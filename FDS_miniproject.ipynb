# %% [markdown]
# # FDS MINI PROJECT

# %% [markdown]
# Topic - data visualization using own datasets

# %% [markdown]
# # Bar Chart

# %% [markdown]
# A bar chart or bar graph is a chart or graph that presents categorical data with rectangular bars with heights or lengths proportional to the values that they represent. The bars can be plotted vertically or horizontally. A vertical bar chart is sometimes called a column chart.

# %%
import pandas as pd
netflix = pd.read_csv("E:/fds_dataset/netflix_titles.csv",index_col=0)
print(netflix.head())
# Out:
#             type                  title         director  \
# show_id
# s1         Movie   Dick Johnson Is Dead  Kirsten Johnson
# s2       TV Show          Blood & Water              NaN
# s3       TV Show              Ganglands  Julien Leclercq
# s4       TV Show  Jailbirds New Orleans              NaN
# s5       TV Show           Kota Factory              NaN
#
#                                                       cast        country  \
# show_id
# s1                                                     NaN  United States
# s2       Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# s3       Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# s4                                                     NaN            NaN
# s5       Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#                  date_added  release_year rating   duration  \
# show_id
# s1       September 25, 2021          2020  PG-13     90 min
# ...

# %%
fig , ax = plt.subplots()
data = netflix['release_year'].value_counts()
points = data.index
frequency = data.values
ax.bar(points, frequency)
ax.set_title('Netflix shows and movies released frequency as per year')
ax.set_xlabel('release_year')
ax.set_ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')

# %%
netflix.groupby("country").release_year.mean().sort_values(ascending=False)[:7].plot.bar()
# Out:
# <AxesSubplot:xlabel='country'>

# %%
netflix.groupby(['type','rating']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='type'>

# %%
netflix['release_year'].value_counts().sort_index().plot.bar()
# Out:
# <AxesSubplot:>

# %%
import pandas as pd
tallestbld = pd.read_csv("E:/fds_dataset/tallest_buildings_global.csv",index_col=0)
print(tallestbld.head())
# Out:
#                                       name  height_m  height_ft  year_built  \
# rank
# 1                             Burj Khalifa     828.0       2717        2010
# 2                              Merdeka 118     678.9       2227        2022
# 3                           Shanghai Tower     632.0       2073        2015
# 4                Abraj Al-Bait Clock Tower     601.0       1972        2012
# 5     Ping An International Finance Centre     599.1       1966        2017
#
#       floors_above  floors_below_ground          city               country
# rank
# 1              163                  1.0         Dubai  United Arab Emirates
# 2              118                  5.0  Kuala Lumpur              Malaysia
# 3              128                  5.0      Shanghai                 China
# 4              120                  3.0         Mecca          Saudi Arabia
# 5              115                  5.0      Shenzhen                 China

# %%
import pandas as pd
from matplotlib import pyplot as plt
tallestbld.plot(x='country', y=['height_m','height_ft'],kind='bar')
# Out:
# <AxesSubplot:xlabel='country'>

# %%
tallestbld.groupby(['country','city']).size().unstack().plot(kind='bar',stacked=True)
# Out:
# <AxesSubplot:xlabel='country'>

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
labels = ['web development','App development','Data analysis','Research and development']
sizes = [20,30,40,10]
explode = (0.1,0.1,0.1,0.4)
fig, ax = plt.subplots()
ax.pie(sizes,
      explode=explode,
      labels=labels,
      autopct='%1.1f%%',
      shadow=True,
      startangle=90)

ax.axis('equal')
ax.set_title('Jobs for computer engineer')
plt.show()
